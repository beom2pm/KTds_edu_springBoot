# %% [markdown]
# <a href="https://colab.research.google.com/github/beom2pm/KTds_edu_springBoot/blob/main/%ED%99%98%EC%9C%A8%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 환율 예측

# %%
import pandas as pd
import numpy as np

exchange_df = pd.read_excel('2019_2025 달러환율.xlsx')
exchange_df
# Out:
#             date exchange_rate
# 0     2025.04.01      1,470.60
# 1     2025.03.31      1,466.50
# 2     2025.03.28      1,466.80
# 3     2025.03.27      1,465.30
# 4     2025.03.26      1,469.60
# ...          ...           ...
# 1537  2019.01.08      1,118.00
# 1538  2019.01.07      1,125.20
# 1539  2019.01.04      1,127.50
# 1540  2019.01.03      1,119.00
# 1541  2019.01.02      1,118.10
#
# [1542 rows x 2 columns]

# %%
import yfinance as yf
import pandas as pd

# 1. KOSPI 종가 데이터 다운로드
kospi = yf.download('^KS11', start='2020-01-01', end='2025-04-01')
kospi = kospi[['Close']].rename(columns={'Close': 'KOSPI'})

# 2. 엑셀 파일로 저장
kospi.to_excel('kospi_data.xlsx')
# Out:
# /tmp/ipython-input-3-4219771724.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   kospi = yf.download('^KS11', start='2020-01-01', end='2025-04-01')
# [*********************100%***********************]  1 of 1 completed
